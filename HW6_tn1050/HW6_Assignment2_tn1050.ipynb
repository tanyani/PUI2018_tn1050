# %% [markdown]
# # SQL CARTO QUERY FUNCTION
# # written for PUI2016_Python2

# %% [markdown]
# ##### This notebook is set up to link as a default to the fb55 account.  To turn in the homework use the citibike dataset - check that you are able to read in about 40k rows

# %%
SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q='

try:
    from urllib.parse import urlparse, urlencode
    from urllib.request import urlopen, Request
    from urllib.error import HTTPError
except ImportError:
    from urlparse import urlparse
    from urllib import urlencode
    from urllib2 import urlopen, Request, HTTPError

try:
    from StringIO import StringIO,BytesIO as io
except ImportError:
    from io import StringIO,BytesIO as io
    
import ast
from IPython.display import display
import pandas as pd

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urlencode({'format': format, 'q': query}).encode('utf-8')
    try:
        response = urlopen(source, data)
    except HTTPError as e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

def fetchSQL(q):
    return pd.read_csv(io(queryCartoDB(q)))

# %%
test = '''
SELECT *
FROM citibike_short
'''

# %%
df = fetchSQL(test)
df.head()
# Out:
#    the_geom  start_station_longitude  the_geom_webmercator  tripduration  \
# 0       NaN               -73.994811                   NaN           801
# 1       NaN               -73.985649                   NaN           245
# 2       NaN               -73.990093                   NaN           379
# 3       NaN               -73.973715                   NaN          2474
# 4       NaN               -74.004704                   NaN           818
#
#        starttime       stoptime  start_station_id  \
# 0  2/1/2015 0:00  2/1/2015 0:14               521
# 1  2/1/2015 1:03  2/1/2015 1:07               438
# 2  2/1/2015 0:00  2/1/2015 0:07               497
# 3  2/1/2015 0:01  2/1/2015 0:42               281
# 4  2/1/2015 0:01  2/1/2015 0:15              2004
#
#                   start_station_name  start_station_latitude  cartodb_id  \
# 0                    8 Ave & W 31 St               40.750450           1
# 1                St Marks Pl & 1 Ave               40.727791          89
# 2                 E 17 St & Broadway               40.737050           2
# 3  Grand Army Plaza & Central Park S               40.764397           3
# 4                  6 Ave & Broome St               40.724399           4
#
#    end_station_id       end_station_name  end_station_latitude  \
# 0             423        W 54 St & 9 Ave             40.765849
# 1             297        E 15 St & 3 Ave             40.734232
# 2             504        1 Ave & E 15 St             40.732219
# 3             127  Barrow St & Hudson St             40.731724
# 4             505        6 Ave & W 33 St             40.749013
#
#    end_station_longitude  bikeid    usertype  birth_year  gender
# 0             -73.986905   17131  Subscriber      1978.0       2
# 1             -73.986923   20142  Subscriber      1990.0       1
# 2             -73.981656   21289  Subscriber      1993.0       1
# 3             -74.006744   18903  Subscriber      1969.0       2
# 4             -73.988484   21044  Subscriber      1985.0       2

# %% [markdown]
# # extra credit: make the function python 2 and 3 compatible so that it works on the  PUI2016_Python3 kernel
# #### The function is now Python 2 and 3 compatible

# %% [markdown]
# ### TASK 1 - Familiarize with SQL Clauses

# %%
task = '''Sort data by start_station_id, tripduration 
    Only checking trips with duration <= 3 hours '''
print(task)
q = '''
SELECT * FROM fb55.citibike
WHERE tripduration > (60*3)
ORDER BY start_station_id, tripduration
'''
display(fetchSQL(q).head())

task = 'Only show the top/last 10 records (aka head and tail in SQL)' 
print(task)
q = '''
SELECT * FROM fb55.citibike LIMIT 10
'''
display(fetchSQL(q))

task = 'List all unique start_station_id values '
print(task)
q = '''
SELECT DISTINCT start_station_id FROM fb55.citibike
'''
display(fetchSQL(q).head())

task = '''Aggregation functions: 
    Count the number of trips (aka wc -l in SQL)
    Find the average/min/max trip duration'''
print(task)
q = '''
SELECT 
    COUNT(*) AS Total_Trips, 
    AVG(tripduration) AS Average_Trip_Duration, 
    MIN(tripduration) AS Minimum_Trip_Duration,
    MAX(tripduration) AS Maximum_Trip_Duration
FROM fb55.citibike
'''
display(fetchSQL(q).head())
# Out:
# Sort data by start_station_id, tripduration
#     Only checking trips with duration <= 3 hours
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN    40772
# 1       NaN   W 52 St & 11 Ave                   NaN    40770
# 2       NaN   W 52 St & 11 Ave                   NaN    22002
# 3       NaN   W 52 St & 11 Ave                   NaN    43107
# 4       NaN   W 52 St & 11 Ave                   NaN    32603
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929           189  2015-02-07 10:40:00+00
# 1               -73.993929           229  2015-02-07 10:40:00+00
# 2               -73.993929           248  2015-02-05 06:19:00+00
# 3               -73.993929           252  2015-02-07 15:43:00+00
# 4               -73.993929           261  2015-02-06 08:58:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-07 10:43:00+00                72       40759
# 1  2015-02-07 10:44:00+00                72       40757
# 2  2015-02-05 06:24:00+00                72       21948
# 3  2015-02-07 15:47:00+00                72       43099
# 4  2015-02-06 09:02:00+00                72       32566
#
#    start_station_latitude  end_station_id  end_station_name  \
# 0               40.767272              72  W 52 St & 11 Ave
# 1               40.767272              72  W 52 St & 11 Ave
# 2               40.767272             478  11 Ave & W 41 St
# 3               40.767272             515  W 43 St & 10 Ave
# 4               40.767272             478  11 Ave & W 41 St
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.767272             -73.993929   18131  Subscriber
# 1             40.767272             -73.993929   19729  Subscriber
# 2             40.760301             -73.998842   16879  Subscriber
# 3             40.760094             -73.994618   15277  Subscriber
# 4             40.760301             -73.998842   18492  Subscriber
#
#    birth_year  gender
# 0      1959.0       2
# 1      1995.0       1
# 2      1970.0       1
# 3      1983.0       1
# 4      1971.0       1
# Only show the top/last 10 records (aka head and tail in SQL)
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN    E 20 St & Park Ave                   NaN      175
# 1       NaN      W 43 St & 10 Ave                   NaN     1159
# 2       NaN     E 6 St & Avenue B                   NaN     2827
# 3       NaN       E 12 St & 3 Ave                   NaN     4961
# 4       NaN       W 41 St & 8 Ave                   NaN     6156
# 5       NaN       5 Ave & E 29 St                   NaN     7433
# 6       NaN  Allen St & Hester St                   NaN     7779
# 7       NaN       E 39 St & 3 Ave                   NaN     8327
# 8       NaN      10 Ave & W 28 St                   NaN     9435
# 9       NaN        E 2 St & 2 Ave                   NaN    10472
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# 2               -73.981854           751  2015-02-01 13:59:00+00
# 3               -73.988900           272  2015-02-01 17:28:00+00
# 4               -73.990026           240  2015-02-01 21:36:00+00
# 5               -73.986831           376  2015-02-02 17:44:00+00
# 6               -73.991908          1217  2015-02-02 20:12:00+00
# 7               -73.976049           441  2015-02-03 08:02:00+00
# 8               -74.001768          1475  2015-02-03 12:31:00+00
# 9               -73.990697           420  2015-02-03 16:45:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-01 11:07:00+00               515        1088
# 2  2015-02-01 14:11:00+00               317        2759
# 3  2015-02-01 17:32:00+00               483        4893
# 4  2015-02-01 21:40:00+00               477        6090
# 5  2015-02-02 17:50:00+00               474        7367
# 6  2015-02-02 20:32:00+00               361        7712
# 7  2015-02-03 08:10:00+00               167        8263
# 8  2015-02-03 12:56:00+00               489        9375
# 9  2015-02-03 16:52:00+00               403       10411
#
#    start_station_latitude  end_station_id         end_station_name  \
# 0               40.738274             229           Great Jones St
# 1               40.760094             490          8 Ave & W 33 St
# 2               40.724537             466          W 25 St & 6 Ave
# 3               40.732233             345          W 13 St & 6 Ave
# 4               40.756405             490          8 Ave & W 33 St
# 5               40.745168             537  Lexington Ave & E 24 St
# 6               40.716059             461          E 20 St & 2 Ave
# 7               40.748901             526          E 33 St & 5 Ave
# 8               40.750664             455          1 Ave & E 44 St
# 9               40.725029             297          E 15 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.727434             -73.993790   19718  Subscriber
# 1             40.751551             -73.993934   21501  Subscriber
# 2             40.743954             -73.991449   14788  Subscriber
# 3             40.736494             -73.997044   16219  Subscriber
# 4             40.751551             -73.993934   18266    Customer
# 5             40.740259             -73.984092   18048  Subscriber
# 6             40.735877             -73.982050   19732    Customer
# 7             40.747659             -73.984907   21518  Subscriber
# 8             40.750020             -73.969053   19863  Subscriber
# 9             40.734232             -73.986923   19257  Subscriber
#
#    birth_year  gender
# 0      1961.0       1
# 1      1981.0       1
# 2      1990.0       1
# 3      1961.0       1
# 4         NaN       0
# 5      1977.0       1
# 6         NaN       0
# 7      1975.0       1
# 8      1984.0       2
# 9      1984.0       1
# List all unique start_station_id values
#    start_station_id  Unnamed: 1
# 0               120         NaN
# 1               285         NaN
# 2               251         NaN
# 3               195         NaN
# 4               453         NaN
# Aggregation functions:
#     Count the number of trips (aka wc -l in SQL)
#     Find the average/min/max trip duration
#    total_trips  average_trip_duration  minimum_trip_duration  \
# 0        46200             675.865823                     60
#
#    maximum_trip_duration
# 0                  43016

# %% [markdown]
# ### TASK 2 - Working with date/time

# %%
print('Selecting trips started on Feb-02-2015 only')
q = '''
SELECT * FROM fb55.citibike
WHERE starttime > '2015-02-02 00:00:00.000'
'''
display(fetchSQL(q).head())
print('''Selecting trips started on the weekends
    What are average trip duration during weekends?''')
q = '''
SELECT AVG(tripduration) AS average_trip_duration_weekends
FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime) IN (0,7)
'''
display(fetchSQL(q).head())
print('Can we do the same for weekday?')
q = '''
SELECT AVG(tripduration) AS average_trip_duration_weekdays
FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime) NOT IN (0,7)
'''
display(fetchSQL(q).head())
# Out:
# Selecting trips started on Feb-02-2015 only
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN       5 Ave & E 29 St                   NaN     7433
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN       E 39 St & 3 Ave                   NaN     8327
# 3       NaN      10 Ave & W 28 St                   NaN     9435
# 4       NaN        E 2 St & 2 Ave                   NaN    10472
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -73.976049           441  2015-02-03 08:02:00+00
# 3               -74.001768          1475  2015-02-03 12:31:00+00
# 4               -73.990697           420  2015-02-03 16:45:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-02 17:50:00+00               474        7367
# 1  2015-02-02 20:32:00+00               361        7712
# 2  2015-02-03 08:10:00+00               167        8263
# 3  2015-02-03 12:56:00+00               489        9375
# 4  2015-02-03 16:52:00+00               403       10411
#
#    start_station_latitude  end_station_id         end_station_name  \
# 0               40.745168             537  Lexington Ave & E 24 St
# 1               40.716059             461          E 20 St & 2 Ave
# 2               40.748901             526          E 33 St & 5 Ave
# 3               40.750664             455          1 Ave & E 44 St
# 4               40.725029             297          E 15 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.740259             -73.984092   18048  Subscriber
# 1             40.735877             -73.982050   19732    Customer
# 2             40.747659             -73.984907   21518  Subscriber
# 3             40.750020             -73.969053   19863  Subscriber
# 4             40.734232             -73.986923   19257  Subscriber
#
#    birth_year  gender
# 0      1977.0       1
# 1         NaN       0
# 2      1975.0       1
# 3      1984.0       2
# 4      1984.0       1
# Selecting trips started on the weekends
#     What are average trip duration during weekends?
#    average_trip_duration_weekends  Unnamed: 1
# 0                        638.1492         NaN
# Can we do the same for weekday?
#    average_trip_duration_weekdays  Unnamed: 1
# 0                      681.975955         NaN

# %% [markdown]
# ### Task 3 - Working with Space

# %%
print('''Showing the list of start station locations
    Using GROUP BY''')
print('''Showing the number of trips started per station''')
print('''… but only for stations within 500m of Time Square!
    The coordinates of Time Square is (40.7577,-73.9857)''')

q = '''
SELECT start_station_id, MIN(start_station_name) AS name, COUNT(*) AS number_of_trips
FROM fb55.citibike
WHERE ST_Distance(
  ST_Point(start_station_longitude,start_station_latitude)::geography,
  ST_Point(-73.9857, 40.7577)::geography
) <= 500
GROUP BY start_station_id
'''
fetchSQL(q)
# Out:
# Showing the list of start station locations
#     Using GROUP BY
# Showing the number of trips started per station
# … but only for stations within 500m of Time Square!
#     The coordinates of Time Square is (40.7577,-73.9857)
#    start_station_id                name  number_of_trips
# 0               173  Broadway & W 49 St              213
# 1               493     W 45 St & 6 Ave              141
# 2              2021     W 45 St & 8 Ave              141
# 3               529     W 42 St & 8 Ave              221
# 4               524     W 43 St & 6 Ave              112
# 5               477     W 41 St & 8 Ave              507
# 6               465  Broadway & W 41 St              251

# %% [markdown]
# ### Task 4 - Putting it all together

# %%
print('''Find the station that had the longest average trip duration during
weekends and within 500m of TimeSquare!''')
q = '''
SELECT start_station_id, MIN(start_station_name) AS name, AVG(tripduration) AS average_trip_duration
FROM fb55.citibike
WHERE ST_Distance(
  ST_Point(start_station_longitude,start_station_latitude)::geography,
  ST_Point(-73.9857, 40.7577)::geography
) <= 500
AND EXTRACT(DOW FROM starttime) IN (0,7)
GROUP BY start_station_id
ORDER BY AVG(tripduration) DESC
LIMIT 1
'''
display(fetchSQL(q))
print('''Extra: create lines for trips started from stations within 500m of Times
Squares and lasted less than 2 hours. The number of trips per each
pair of stations are output as attributes of these lines. ''')
# Out:
# Find the station that had the longest average trip duration during
# weekends and within 500m of TimeSquare!
#    start_station_id             name  average_trip_duration
# 0              2021  W 45 St & 8 Ave             799.722222
# Extra: create lines for trips started from stations within 500m of Times
# Squares and lasted less than 2 hours. The number of trips per each
# pair of stations are output as attributes of these lines.

# %%
q = '''
SELECT 
    start_station_id, MIN(start_station_name) AS start_name, 
    end_station_id, MIN(end_station_name) AS end_name, 
    COUNT(*) AS number_of_trips
FROM fb55.citibike
WHERE ST_Distance(
  ST_Point(start_station_longitude,start_station_latitude)::geography,
  ST_Point(-73.9857, 40.7577)::geography
) <= 500
AND tripduration/60 < 120
GROUP BY start_station_id, end_station_id
'''
fetchSQL(q)
# Out:
#      start_station_id          start_name  end_station_id  \
# 0                 173  Broadway & W 49 St              72
# 1                 173  Broadway & W 49 St             137
# 2                 173  Broadway & W 49 St             160
# 3                 173  Broadway & W 49 St             164
# 4                 173  Broadway & W 49 St             168
# 5                 173  Broadway & W 49 St             173
# 6                 173  Broadway & W 49 St             228
# 7                 173  Broadway & W 49 St             285
# 8                 173  Broadway & W 49 St             300
# 9                 173  Broadway & W 49 St             305
# 10                173  Broadway & W 49 St             318
# 11                173  Broadway & W 49 St             325
# 12                173  Broadway & W 49 St             352
# 13                173  Broadway & W 49 St             358
# 14                173  Broadway & W 49 St             359
# 15                173  Broadway & W 49 St             376
# 16                173  Broadway & W 49 St             383
# 17                173  Broadway & W 49 St             385
# 18                173  Broadway & W 49 St             402
# 19                173  Broadway & W 49 St             422
# 20                173  Broadway & W 49 St             423
# 21                173  Broadway & W 49 St             435
# 22                173  Broadway & W 49 St             438
# 23                173  Broadway & W 49 St             442
# 24                173  Broadway & W 49 St             444
# 25                173  Broadway & W 49 St             447
# 26                173  Broadway & W 49 St             448
# 27                173  Broadway & W 49 St             450
# 28                173  Broadway & W 49 St             459
# 29                173  Broadway & W 49 St             462
# ..                ...                 ...             ...
# 542              2021     W 45 St & 8 Ave             479
# 543              2021     W 45 St & 8 Ave             480
# 544              2021     W 45 St & 8 Ave             482
# 545              2021     W 45 St & 8 Ave             488
# 546              2021     W 45 St & 8 Ave             489
# 547              2021     W 45 St & 8 Ave             490
# 548              2021     W 45 St & 8 Ave             492
# 549              2021     W 45 St & 8 Ave             495
# 550              2021     W 45 St & 8 Ave             496
# 551              2021     W 45 St & 8 Ave             499
# 552              2021     W 45 St & 8 Ave             508
# 553              2021     W 45 St & 8 Ave             509
# 554              2021     W 45 St & 8 Ave             510
# 555              2021     W 45 St & 8 Ave             512
# 556              2021     W 45 St & 8 Ave             513
# 557              2021     W 45 St & 8 Ave             514
# 558              2021     W 45 St & 8 Ave             515
# 559              2021     W 45 St & 8 Ave             520
# 560              2021     W 45 St & 8 Ave             521
# 561              2021     W 45 St & 8 Ave             525
# 562              2021     W 45 St & 8 Ave             526
# 563              2021     W 45 St & 8 Ave             529
# 564              2021     W 45 St & 8 Ave             530
# 565              2021     W 45 St & 8 Ave             537
# 566              2021     W 45 St & 8 Ave             538
# 567              2021     W 45 St & 8 Ave             546
# 568              2021     W 45 St & 8 Ave            2006
# 569              2021     W 45 St & 8 Ave            2017
# 570              2021     W 45 St & 8 Ave            2021
# 571              2021     W 45 St & 8 Ave            2023
#
#                           end_name  number_of_trips
# 0                 W 52 St & 11 Ave                5
# 1            E 56 St & Madison Ave                2
# 2          E 37 St & Lexington Ave                1
# 3                  E 47 St & 2 Ave                4
# 4                  W 18 St & 6 Ave                2
# 5               Broadway & W 49 St                6
# 6                  E 48 St & 3 Ave                7
# 7               Broadway & E 14 St                1
# 8           Shevchenko Pl & E 7 St                1
# 9                  E 58 St & 3 Ave                1
# 10        E 43 St & Vanderbilt Ave               15
# 11                 E 19 St & 3 Ave                1
# 12                 W 56 St & 6 Ave                1
# 13   Christopher St & Greenwich St                1
# 14              E 47 St & Park Ave                9
# 15            John St & William St                1
# 16      Greenwich Ave & Charles St                1
# 17                 E 55 St & 2 Ave                1
# 18              Broadway & E 22 St                2
# 19                W 59 St & 10 Ave                2
# 20                 W 54 St & 9 Ave                1
# 21                 W 21 St & 6 Ave                1
# 22             St Marks Pl & 1 Ave                1
# 23                 W 27 St & 7 Ave                4
# 24              Broadway & W 24 St                1
# 25                 8 Ave & W 52 St                2
# 26                W 37 St & 10 Ave                2
# 27                 W 49 St & 8 Ave                2
# 28                W 20 St & 11 Ave                2
# 29                W 22 St & 10 Ave                4
# ..                             ...              ...
# 542                9 Ave & W 45 St                1
# 543               W 53 St & 10 Ave                1
# 544                W 15 St & 7 Ave                2
# 545                W 39 St & 9 Ave                3
# 546               10 Ave & W 28 St                1
# 547                8 Ave & W 33 St               10
# 548                W 33 St & 7 Ave                3
# 549               W 47 St & 10 Ave                4
# 550                E 16 St & 5 Ave                2
# 551             Broadway & W 60 St                2
# 552               W 46 St & 11 Ave                2
# 553                9 Ave & W 22 St                4
# 554                W 51 St & 6 Ave                2
# 555                W 29 St & 9 Ave                3
# 556               W 56 St & 10 Ave                1
# 557               12 Ave & W 40 St                2
# 558               W 43 St & 10 Ave                4
# 559                W 52 St & 5 Ave                1
# 560                8 Ave & W 31 St                2
# 561               W 34 St & 11 Ave                1
# 562                E 33 St & 5 Ave                1
# 563                W 42 St & 8 Ave                1
# 564               11 Ave & W 59 St                3
# 565        Lexington Ave & E 24 St                1
# 566          E 48 St & Madison Ave                1
# 567           E 30 St & Park Ave S                1
# 568         Central Park S & 6 Ave                2
# 569                E 43 St & 2 Ave                1
# 570                W 45 St & 8 Ave                7
# 571        E 55 St & Lexington Ave                1
#
# [572 rows x 5 columns]
